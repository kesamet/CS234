# %% [markdown]
# # Assignment 1 solution

# %%
import numpy as np
import gym
import time
from lake_envs import *

# %load_ext autoreload
# %autoreload 2

import vi_and_pi as F

# %% [markdown]
# ### Deterministic-4x4-FrozenLake-v0
#
# (prob, nextstate, reward, terminal)

# %%
env = gym.make("Deterministic-4x4-FrozenLake-v0")
env.P
# Out:
# {0: {0: [(1.0, 0, 0.0, False)],
#   1: [(1.0, 4, 0.0, False)],
#   2: [(1.0, 1, 0.0, False)],
#   3: [(1.0, 0, 0.0, False)]},
#  1: {0: [(1.0, 0, 0.0, False)],
#   1: [(1.0, 5, 0.0, True)],
#   2: [(1.0, 2, 0.0, False)],
#   3: [(1.0, 1, 0.0, False)]},
#  2: {0: [(1.0, 1, 0.0, False)],
#   1: [(1.0, 6, 0.0, False)],
#   2: [(1.0, 3, 0.0, False)],
#   3: [(1.0, 2, 0.0, False)]},
#  3: {0: [(1.0, 2, 0.0, False)],
#   1: [(1.0, 7, 0.0, True)],
#   2: [(1.0, 3, 0.0, False)],
#   3: [(1.0, 3, 0.0, False)]},
#  4: {0: [(1.0, 4, 0.0, False)],
#   1: [(1.0, 8, 0.0, False)],
#   2: [(1.0, 5, 0.0, True)],
#   3: [(1.0, 0, 0.0, False)]},
#  5: {0: [(1.0, 5, 0, True)],
#   1: [(1.0, 5, 0, True)],
#   2: [(1.0, 5, 0, True)],
#   3: [(1.0, 5, 0, True)]},
#  6: {0: [(1.0, 5, 0.0, True)],
#   1: [(1.0, 10, 0.0, False)],
#   2: [(1.0, 7, 0.0, True)],
#   3: [(1.0, 2, 0.0, False)]},
#  7: {0: [(1.0, 7, 0, True)],
#   1: [(1.0, 7, 0, True)],
#   2: [(1.0, 7, 0, True)],
#   3: [(1.0, 7, 0, True)]},
# ...

# %%
print("\n" + "-"*25 + "\nBeginning Policy Iteration\n" + "-"*25)

V_pi, p_pi = F.policy_iteration(env.P, env.nS, env.nA, gamma=0.9, tol=1e-3)
F.render_single(env, p_pi, 100)
# Out:
# -------------------------
# Beginning Policy Iteration
# -------------------------
#
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
# Episode reward: 1.000000

# %%
V_pi
# Out:
# array([0.59 , 0.656, 0.729, 0.656, 0.656, 0.   , 0.81 , 0.   , 0.729,
#        0.81 , 0.9  , 0.   , 0.   , 0.9  , 1.   , 0.   ])

# %%
p_pi
# Out:
# array([1, 2, 1, 0, 1, 0, 1, 0, 2, 1, 1, 0, 0, 2, 2, 0])

# %% [markdown]
# ### Stochastic-4x4-FrozenLake-v0

# %%
env = gym.make("Stochastic-4x4-FrozenLake-v0")
env.P
# Out:
# {0: {0: [(0.3333333333333333, 0, 0.0, False),
#    (0.3333333333333333, 0, 0.0, False),
#    (0.3333333333333333, 4, 0.0, False)],
#   1: [(0.3333333333333333, 0, 0.0, False),
#    (0.3333333333333333, 4, 0.0, False),
#    (0.3333333333333333, 1, 0.0, False)],
#   2: [(0.3333333333333333, 4, 0.0, False),
#    (0.3333333333333333, 1, 0.0, False),
#    (0.3333333333333333, 0, 0.0, False)],
#   3: [(0.3333333333333333, 1, 0.0, False),
#    (0.3333333333333333, 0, 0.0, False),
#    (0.3333333333333333, 0, 0.0, False)]},
#  1: {0: [(0.3333333333333333, 1, 0.0, False),
#    (0.3333333333333333, 0, 0.0, False),
#    (0.3333333333333333, 5, 0.0, True)],
#   1: [(0.3333333333333333, 0, 0.0, False),
#    (0.3333333333333333, 5, 0.0, True),
#    (0.3333333333333333, 2, 0.0, False)],
#   2: [(0.3333333333333333, 5, 0.0, True),
#    (0.3333333333333333, 2, 0.0, False),
#    (0.3333333333333333, 1, 0.0, False)],
#   3: [(0.3333333333333333, 2, 0.0, False),
# ...

# %%
print("\n" + "-"*25 + "\nBeginning Value Iteration\n" + "-"*25)

V_vi, p_vi = F.value_iteration(env.P, env.nS, env.nA, gamma=0.9, tol=1e-3)
F.render_single(env, p_vi, 100)
# Out:
# -------------------------
# Beginning Value Iteration
# -------------------------
#
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
# ...

# %%
V_vi
# Out:
# array([0.063, 0.056, 0.071, 0.052, 0.086, 0.   , 0.11 , 0.   , 0.141,
#        0.244, 0.297, 0.   , 0.   , 0.378, 0.638, 0.   ])

# %%
p_vi
# Out:
# array([0, 3, 0, 3, 0, 0, 0, 0, 3, 1, 0, 0, 0, 2, 1, 0])
